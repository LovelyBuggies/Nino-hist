# %%
import hist
import numpy as np

# %%
h = hist.Hist(
    hist.axis.Regular(50, -3, 3, name="S",title="s [units]", underflow=False, overflow=False)
)

data = np.random.normal(size=1_000)
h.fill(data)
h.view()
# Out:
# array([ 1.,  0.,  1.,  3.,  2.,  3.,  5.,  7.,  4.,  8., 12., 14., 12.,
#        14., 19., 28., 23., 25., 40., 43., 53., 47., 43., 44., 44., 43.,
#        44., 38., 43., 39., 48., 38., 42., 29., 28., 26., 14., 12., 15.,
#        12.,  7., 10.,  8.,  2.,  3.,  1.,  2.,  0.,  0.,  0.])

# %%
def pdf(x):
    return 1/np.sqrt(2*np.pi) * np.exp(-.5*x**2)

# %%
nino = True
# ax1, ax2 = h.pull_plot(nino)
ax1, ax2 = h.pull_plot(pdf)
# Out:
# /Users/nino/Documents/GitHub/Nino-Hist/src/hist/general.py:26: RuntimeWarning: divide by zero encountered in true_divide
#   pulls = (self.view() - values) / yerr
