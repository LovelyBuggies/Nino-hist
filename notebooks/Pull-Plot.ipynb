# %%
import hist
import numpy as np

# %%
h = hist.Hist(
    hist.axis.Regular(50, -3, 3, name="S",title="s [units]", underflow=False, overflow=False)
)

data = np.random.normal(size=1_000)
h.fill(data)
# h.view()
# Out:
# Hist(Regular(50, -3, 3, underflow=False, overflow=False, metadata={'name': 'S', 'title': 's [units]'}), storage=Double()) # Sum: 999.0

# %%
def pdf(x):
    return 1/np.sqrt(2*np.pi) * np.exp(-.5*x**2)

# %%
nino = True
# ax1, ax2 = h.pull_plot(nino)     # "Only callable parameter is accepted in pull plot."
fig, ax1, pull_ax = h.pull_plot(pdf, size="l")
# Out:
# /Users/nino/Documents/GitHub/Nino-Hist/src/hist/general.py:77: RuntimeWarning: divide by zero encountered in true_divide
#   pulls = (self.view() - values) / yerr
